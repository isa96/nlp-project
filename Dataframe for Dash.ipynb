# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('df_sample.csv')
data.head()
# Out:
#    Age                     Title  \
# 0   37  Better than i expected!!
# 1   37              Really cute!
# 2   63    Design too fluorescent
# 3   34                   Classic
# 4   44                      Boxy
#
#                                               Review  Rating  Recommend  \
# 0  These are colors i normally never wear...baby ...       5          1
# 1  What a great, easy to wear jumpsuit! i love th...       5          1
# 2  I loved the lavender color on the cape. it was...       3          1
# 3  This dress is beautifully constructed. it is v...       5          1
# 4  This sweater was unflattering me, very boxy an...       3          0
#
#    Positive Feedback Count Department Name  Class Name  Review Length
# 0                        4            Tops  Fine gauge            523
# 1                        1         Bottoms       Pants            297
# 2                        0        Intimate      Lounge            522
# ...

# %%
data_1 = pd.read_csv('dash_df.csv')
data_1.head()
# Out:
#    Age                      Title  \
# 0   49  A little too flowy for me
# 1   38       Cute dress size down
# 2   61                Weird shape
# 3   56                Great shirt
# 4   69      So cute and great fit
#
#                                               Review  Rating  Recommend  \
# 0  This is a really cute dress, just did not look...       2          1
# 1  I'm usually a 6 in dresses and the 6 here fit ...       3          1
# 2  The pattern is very adorable. unfortunately th...       2          0
# 3  This shirt is more stunning in person. the col...       5          1
# 4  I am so pleased with this top! it is slightly ...       5          1
#
#    Positive Feedback Count   Division Name Department Name Class Name  \
# 0                        1  General Petite         Dresses    Dresses
# 1                        6  General Petite         Dresses    Dresses
# 2                       23         General            Tops    Blouses
# ...
